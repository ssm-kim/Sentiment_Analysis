# %% [markdown]
# **참고자료**
# <br>
# <br>
#  * https://somjang.tistory.com/entry/Keras%EA%B8%B0%EC%82%AC-%EC%A0%9C%EB%AA%A9%EC%9D%84-%EA%B0%80%EC%A7%80%EA%B3%A0-%EA%B8%8D%EC%A0%95-%EB%B6%80%EC%A0%95-%EC%A4%91%EB%A6%BD-%EB%B6%84%EB%A5%98%ED%95%98%EB%8A%94-%EB%AA%A8%EB%8D%B8-%EB%A7%8C%EB%93%A4%EC%96%B4%EB%B3%B4%EA%B8%B0
# <br>
# <br>
#  * https://github.com/sbomhoo/naver_news_crawling/blob/master/README.md

# %% [markdown]
# # 네이버 기사 감정 분석
#
# ## 데이터 불러오기
# <br>
#
# **데이터 특성 정의( 각각의 데이터가 어떤 특성을 가지는지? )**
#
#     ▶ date : 등록된 기사별 날짜
#     ▶ title : 기사 제목
#     ▶ source : 언론사
#     ▶ contents : 기사 내용 요약본
#     ▶ link : 사이트 주소
#
# ※ : 네이버 뉴스 기준으로 Test... ( 구글 뉴스데이터와 병합해서 전처리 실시 예정 )

# %%
import pandas as pd
import numpy as np
import matplotlib
import datetime, time
import re
import timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 시각화 글자 깨짐 방지
import os

if os.name == 'posix':
    plt.rc("font", family="AppleGothic")
else:
    plt.rc("font", family="Malgun Gothic")

# %%
matplotlib.rc('font',family='NanumGothic')

# 한글 폰트 적용
matplotlib.rc('axes', unicode_minus = False) # True

# 2022 / 04 / 21 일자 스크래핑 데이터
# df_news = pd.read_csv('./news_data.csv', engine= 'python',encoding = 'utf-8')
df_news = pd.read_csv('./news_data(2021.05.01 ~ 2022.05.01 검색어-DGB대구은행).csv', engine= 'python',encoding = 'utf-8')

# (행, 열)
print(df_news.shape)
df_news.head(1)
# Out:
# (12867, 12)
#    Unnamed: 0         date                     title   source  \
# 0           0  2021.05.01.  DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
#
#                                             contents  \
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...
#
#                                                 link Unnamed: 6 Unnamed: 7  \
# 0  http://www.g-enews.com/ko-kr/news/article/news...        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN        NaN         NaN         NaN

# %%
# 데이터 구조 파악시 용이
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12867 entries, 0 to 12866
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   12867 non-null  int64
#  1   date         12867 non-null  object
#  2   title        12867 non-null  object
#  3   source       12867 non-null  object
#  4   contents     12864 non-null  object
#  5   link         12867 non-null  object
#  6   Unnamed: 6   108 non-null    object
#  7   Unnamed: 7   65 non-null     object
#  8   Unnamed: 8   14 non-null     object
#  9   Unnamed: 9   14 non-null     object
#  10  Unnamed: 10  6 non-null      object
#  11  Unnamed: 11  5 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 1.2+ MB

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 이상치와 결측치 제거 / 데이터 특성(구조) 확인
#     ▶ 필요없는 컬럼 제거
#     ▶ 컬럼명과 순서 변경
#     ▶ 데이터 구조 파악 - info, head
#
#     ▶ 우선 'DGB대구은행'과 필요없는 언론사는 버리고 인덱스번호도 초기화 시켜야 함.
#     예를 들면, 축구관련 기사
#
#     제목과 요약본 기준
#     '감독' / '신태용' / 'DGB대구은행파크' / '대표팀' / '경기' / '스포츠' / '축구'
#     참고 사이트 : https://jimmy-ai.tistory.com/92
# ※ : 수치별 데이터가 아니므로 이상치는 굳이 확인할 필요가 없다고 판단

# %%
# 필요한 데이터만 추출
df_news = df_news.loc[:,['date', 'title', 'source', 'contents']]

# 컬럼명 변경
df_news.rename(columns={'source' : 'press'}, inplace=True)

# %%
df_news.head(1)
# Out:
#           date                     title    press  \
# 0  2021.05.01.  DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...

# %%
# 행별로 null값 존재 유무 파악 --> 결측치 contents쪽에 3개 존재.
df_news.isnull().sum(axis = 0)
# Out:
# date        0
# title       0
# press       0
# contents    3
# dtype: int64

# %%
# 불필요한 내용 삭제 / contents의 길이가 20이하 또는 title의 길이가 10 이하인 데이터
df_news.head()

# 51개 스크래핑 오류
print(len(df_news[df_news['contents'].str.contains('오류', na=False)]))
df_news[df_news['contents'].str.contains('오류', na=False)][:5]

for i in df_news[df_news['contents'].str.contains('오류', na=False)].index:
    df_news.drop(i, axis=0, inplace=True)
# Out:
# 51

# %%
df_news.head(1)
# Out:
#           date                     title    press  \
# 0  2021.05.01.  DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...

# %%
# 중복행 제거 --> 분석하는데 안 좋을 수도 있으니 신중한 고려가 필요함.
# 참고 : https://sy-log.tistory.com/60

print(df_news.shape)
print(len(df_news))
# 중복행 살림.
print('중복행 갯수 : %d개' % df_news.duplicated().sum())
df_news.drop_duplicates(['title'], keep = False)
# Out:
# (12816, 4)
# 12816
# 중복행 갯수 : 165개
#               date                                 title    press  \
# 0      2021.05.01.              DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
# 2      2021.05.01.          은행·비은행 동반성장…지방금융지주 1분기 '好好好'     미디어펜
# 3      2021.05.01.     DGB대구銀, 코로나 대응 관련 ‘유공 행정안전부 장관표창’     더퍼블릭
# 4      2021.05.01.       대구은행, 방역취약계층 어르신 대상 KF94 마스크 전달     일요신문
# 5      2021.05.01.         지방금융그룹도 1분기 사상최대 실적…비은행 계열 선전    e대한경제
# ...            ...                                   ...      ...
# 12861         4일 전        TBC)DGB금융그룹 1분기 지배주주 순이익 사상 최대  TBC대구방송
# 12863         4일 전             대구은행, 선거 자금 관리 '당선 통장' 판매     대구신문
# 12864         4일 전      DGB대구은행, 선거자금 관리 전용 ‘DGB당선통장’ 판매     뉴데일리
# 12865         4일 전  DGB대구은행, ‘ESG경영 실천’ 종량제 봉투 나눔 캠페인 실시     뉴데일리
# 12866         4일 전      DGB대구은행, ‘포스트 팬데믹’ 가정의 달 행사 ‘풍성’     뉴데일리
#
#                                                 contents
# 0      DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...
# 2      DGB금융의 순이익은 지난해 1분기에 견줘 40% 급증했다. 핵심 계열사인 대구은행...
# 3      DGB대구은행(이하 대구은행)은 코로나19 재난 방역 적극 참여 및 지역사회 지원활...
# 4      - DGB대구은행, 어버이날 맞아 효(孝) 마스크 지원 DGB대구은행(은행장 임성훈...
# 5      시장금리 상승세에 힘입어 대구은행의 순이자마진이 회복한 데 이어, 비은행 계열인 하...
# ...                                                  ...
# 12861  주력 계열사인 DGB대구은행 순이익은 29.7% 늘어난 천 187억원을 기록했습니다...
# 12863  DGB대구은행은 오는 6월1일 '제8회 전국동시지방선거'를 앞두고 선거 자금을 관리...
# 12864  뉴데일리 강승탁 기자 = DGB대구은행(은행장 임성훈)은 오는 6월 1일 ‘제8회 ...
# 12865  뉴데일리 강승탁 기자 = DGB대구은행(은행장 임성훈)은 2022년 한 해를 ESG...
# 12866  뉴데일리 강승탁 기자 = DGB대구은행(은행장 임성훈)은 ‘가정의 달’ 5월을 맞아...
#
# [10691 rows x 4 columns]

# %%
# 중복 제거 일부러 하지 않음.
len(df_news)
# Out:
# 12816

# %%
# AND용
# target_string = ['서울', '마포']
# df[df['주소'].map(lambda x: all(string in x for string in target_string))]
# df_news.head()

# %%
# df.query('주소.str.contains("마포|은평")', engine='python'
# Series 내장함수 : str.contains() 

# 제목
remove_title = list(df_news.query('title.str.contains("부상|선수|승점|구장|리그|DGB대구은행파크|FC|감독|신태용|연승|대표팀|친선경기|스포츠|축구|세징야", na=False)', engine = 'python').index)
df_news.drop(remove_title, axis=0, inplace = True)

# 내용 요약본
remove_contents = list(df_news.query('contents.str.contains("부상|선수|승점|구장|리그|DGB대구은행파크|FC|감독|신태용|연승|대표팀|친선경기|스포츠|축구|세징야", na=False)', engine = 'python').index)
df_news.drop(remove_contents, axis=0, inplace = True)

# %% [markdown]
# ### 결측치 처리 contents 컬럼에 3개 존재 --> 3개의 데이터 삭제

# %%
df_news.count()
# Out:
# date        9000
# year        9000
# month       9000
# day         9000
# title       9000
# press       9000
# contents    8997
# dtype: int64

# %%
print(df_news.isnull().sum())
df_news.dropna(axis=0, inplace = True)
# Out:
# date        0
# year        0
# month       0
# day         0
# title       0
# press       0
# contents    3
# dtype: int64

# %%
df_news.shape
# Out:
# (8997, 7)

# %%
# 인덱스 번호 새로 부여.
df_news.reset_index(inplace=True)
df_news.drop(['index'], axis=1, inplace=True)

# %%
df_news.tail(50)
# Out:
#            date  year  month  day  \
# 8947 2022-04-14  2022      4   14
# 8948 2022-04-14  2022      4   14
# 8949 2022-04-14  2022      4   14
# 8950 2022-04-14  2022      4   14
# 8951 2022-04-14  2022      4   14
# 8952 2022-04-14  2022      4   14
# 8953 2022-04-14  2022      4   14
# 8954 2022-04-14  2022      4   14
# 8955 2022-04-14  2022      4   14
# 8956 2022-04-14  2022      4   14
# 8957 2022-04-14  2022      4   14
# 8958 2022-04-14  2022      4   14
# 8959 2022-04-14  2022      4   14
# 8960 2022-04-14  2022      4   14
# 8961 2022-04-14  2022      4   14
# 8962 2022-04-14  2022      4   14
# 8963 2022-04-14  2022      4   14
# 8964 2022-04-15  2022      4   15
# 8965 2022-04-15  2022      4   15
# 8966 2022-04-15  2022      4   15
# 8967 2022-04-15  2022      4   15
# 8968 2022-04-15  2022      4   15
# 8969 2022-04-15  2022      4   15
# 8970 2022-04-15  2022      4   15
# 8971 2022-04-15  2022      4   15
# 8972 2022-04-15  2022      4   15
# 8973 2022-04-15  2022      4   15
# 8974 2022-04-15  2022      4   15
# 8975 2022-04-15  2022      4   15
# 8976 2022-04-15  2022      4   15
# 8977 2022-04-15  2022      4   15
# 8978 2022-04-15  2022      4   15
# 8979 2022-04-15  2022      4   15
# 8980 2022-04-15  2022      4   15
# 8981 2022-04-15  2022      4   15
# 8982 2022-04-15  2022      4   15
# 8983 2022-04-15  2022      4   15
# 8984 2022-04-16  2022      4   16
# 8985 2022-04-16  2022      4   16
# 8986 2022-04-16  2022      4   16
# 8987 2022-04-17  2022      4   17
# 8988 2022-04-17  2022      4   17
뉴데일리 강승탁 기자 = DGB대구은행(은행장 임성훈)은 오는 6월 1일 ‘제8회 ...
# 8995  뉴데일리 강승탁 기자 = DGB대구은행(은행장 임성훈)은 2022년 한 해를 ESG...
# 8996  뉴데일리 강승탁 기자 = DGB대구은행(은행장 임성훈)은 ‘가정의 달’ 5월을 맞아...

# %% [markdown]
# ## 날짜 데이터 정제
#     ▶ 연월일로만 표현 ( 시간 제거 )
#     ▶ 연 / 월 / 일 3개의 파생변수 생성
#     ▶ 연 / 일 보다는 월별로 각 언론사의 'DGB대구은행'에 관련된 기사가 얼마나 많은지? 파악하기 위함. --> 긍정 / 부정 개수로 이어짐.

# %%
# 연도별 월별 일별로 
df_news['date']
# Out:
# 0      2021-05-01
# 1      2021-05-01
# 2      2021-05-01
# 3      2021-05-01
# 4      2021-05-01
#           ...
# 8992   2022-04-17
# 8993   2022-04-17
# 8994   2022-04-17
# 8995   2022-04-17
# 8996   2022-04-17
# Name: date, Length: 8997, dtype: datetime64[ns]

# %%
now = time.localtime()

# 테스트 용 / 참고 - https://wikidocs.net/104836
print(datetime.datetime.now())
print('{}년 {}월 {}일'.format(now.tm_year, now.tm_mon, now.tm_mday-1))
print(pd.to_datetime(df_news['date'][0]) - datetime.timedelta(days = 6))
# Out:
# 2022-05-09 11:17:50.466135
# 2022년 5월 8일
# 2021-04-25 00:00:00

# %%
# 2022-04-21 17:45 일자 데이터 자료 ( 시각은 무시 )
scrapping_date = datetime.date(2022, 4, 21)

idx_list = list()

for i in range(len(df_news['date'])):
    if '일' in df_news['date'][i]:
        idx_list.append(i)
    elif '시간' in df_news['date'][i]:
        idx_list.append(i)
# df_news['date'][i]
# 몇 일전 / 몇 시간전 인덱스 번호
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-217-6b143ae8d9fe> in <module>
#       5
#       6 for i in range(len(df_news['date'])):
# ----> 7     if '일' in df_news['date'][i]:
#       8         idx_list.append(i)
#       9     elif '시간' in df_news['date'][i]:
#
# TypeError: argument of type 'Timestamp' is not iterable

# %%
# 시간 전 / 몇일 전 --> 숫자로 변환

for i in idx_list:
    # '\d+'은 정수만 추출
    trans_day = int(re.findall('\d+', df_news['date'][i])[0]) 
    # 시간 전은 -1일로 통일?
    if '시간' in df_news['date'][i]:
        df_news['date'][i] = scrapping_date - datetime.timedelta(days=1)
    else:
        df_news['date'][i] = scrapping_date - datetime.timedelta(days=trans_day)

# %%
df_news['date'] = pd.to_datetime(df_news['date'])

# %%
df_news['year'] = df_news['date'].dt.year
df_news['month'] = df_news['date'].dt.month
df_news['day'] = df_news['date'].dt.day

# %%
df_news.head(1)
# Out:
#         date  year  month  day                     title    press  \
# 0 2021-05-01  2021      5    1  DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...

# %%
# 데이터 자료 시간에서 마이너스해주면 날짜가 나옴.
# 이것을 다시 대입해주면 날짜 데이터 정제 완료

# 컬럼 제거 axis = 1 --> 열 / axis = 0 --> 행
# df_news.drop(['date_day'], axis=1, inplace=True)

# %%
# 참고 : https://hogni.tistory.com/51
# 컬럼 순서 정렬
df_news = df_news[['date', 'year', 'month', 'day', 'title', 'press', 'contents']]

# %%
df_news.head()
# Out:
#         date  year  month  day                              title    press  \
# 0 2021-05-01  2021      5    1           DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
# 1 2021-05-01  2021      5    1       DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원     경북신문
# 2 2021-05-01  2021      5    1       은행·비은행 동반성장…지방금융지주 1분기 '好好好'     미디어펜
# 3 2021-05-01  2021      5    1  DGB대구銀, 코로나 대응 관련 ‘유공 행정안전부 장관표창’     더퍼블릭
# 4 2021-05-01  2021      5    1    대구은행, 방역취약계층 어르신 대상 KF94 마스크 전달     일요신문
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...
# 1  DGB대구은행(은행장 임성훈)은 다가오는 어버이날을 맞아 지역 내 방역취약계층 어르...
# 2  DGB금융의 순이익은 지난해 1분기에 견줘 40% 급증했다. 핵심 계열사인 대구은행...
# 3  DGB대구은행(이하 대구은행)은 코로나19 재난 방역 적극 참여 및 지역사회 지원활...
# 4  - DGB대구은행, 어버이날 맞아 효(孝) 마스크 지원 DGB대구은행(은행장 임성훈...

# %% [markdown]
# ## 정규식 표현 처리
#
# <br>
#
# '[-=+,#/\?:^$.@*\"※%~&ㆍ\‘\’\_, ②外∙·!』『\(\)\[\]\[\]\<\>\'\`<\>\銀…\"\'…》]' 등을 기사제목에서 제거
# - tqdm --> 진행률 표시 모듈
#
# **※ 참고 : https://clolee.tistory.com/17**
# <br>

# %% [markdown]
# ### 참고 문법

# %%
def cleasing(text):
    repl =''
    pattern = '([ㄱ-ㅎㅏ-ㅣ]+)' # 자음, 모음 제거
    text = re.sub(pattern= pattern, repl=repl, string=text) #pattern = '[^\w\s]' # 특수기호 제거 
    pattern = '[^가-히\s]' # 특수기호 제거 
    text = re.sub(pattern= pattern, repl=repl, string=text) 
    pattern = '<[^>]*>' # html 제거 
    text = re.sub(pattern = pattern, repl='',string=text) 
    return text
# 참고 : https://codingspooning.tistory.com/138

# 1. df_news_copy['title'].map(lambda x: cleasing(x))

# 2. [re.sub('[^A-Za-z0-9가-힣]', ' ', s) for s in df_news_copy['title']]

# 3. df_news_copy['title'].str.replace(pat=r'[^\w]', repl=r' ', regex=True)[:30]

# %% [markdown]
# ### 정규식 표현 실시

# %%
from tqdm import tqdm
import copy

# 경고 off
pd.set_option('mode.chained_assignment', None)

# 원본 데이터프레임 복사하여 사용
df_news_copy = copy.deepcopy(df_news)
df_news_copy.insert(5, 'nouns_title', '0')
title_data = df_news_copy['title'].tolist()

# re.sub('[-=+,#/\?:^$.@*\"※%~&ㆍ\‘\’\_, ②外∙·!』『\(\)\[\]\[\]\<\>\'\`<\>\銀…\"\'…》→p”“◇證‧]',
for i in range(len(title_data)):
    cleaner = re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·◇②【】<>�→α]', '', title_data[i])
    df_news_copy['nouns_title'][i] = cleaner

df_news_copy.loc[:5,['nouns_title']]
# Out:
#                       nouns_title
# 0         DGB대구은행 은행권 중금리대출 실적 1위
# 1       DGB대구은행 어버이날 맞이 효孝 마스크 지원
# 2        은행비은행 동반성장지방금융지주 1분기 好好好
# 3  DGB대구銀 코로나 대응 관련 유공 행정안전부 장관표창
# 4  대구은행 방역취약계층 어르신 대상 KF94 마스크 전달
# 5    지방금융그룹도 1분기 사상최대 실적비은행 계열 선전

# %%
df_news_copy.head(3)
# Out:
#         date  year  month  day                         title  \
# 0 2021-05-01  2021      5    1      DGB대구은행, 은행권 중금리대출 실적 1위
# 1 2021-05-01  2021      5    1  DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원
# 2 2021-05-01  2021      5    1  은행·비은행 동반성장…지방금융지주 1분기 '好好好'
#
#                  nouns_title    press  \
# 0    DGB대구은행 은행권 중금리대출 실적 1위  글로벌이코노믹
# 1  DGB대구은행 어버이날 맞이 효孝 마스크 지원     경북신문
# 2   은행비은행 동반성장지방금융지주 1분기 好好好     미디어펜
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...
# 1  DGB대구은행(은행장 임성훈)은 다가오는 어버이날을 맞아 지역 내 방역취약계층 어르...
# 2  DGB금융의 순이익은 지난해 1분기에 견줘 40% 급증했다. 핵심 계열사인 대구은행...

# %% [markdown]
# ## 토큰화 및 불용어 제거
#
# <br>
#
# **Hannanum / Kkma / Komoran / Mecab / Twitter(Okt, 사용?)**
# - 제목을 토큰화 시킴
# - Okt형태소 분석기 사용
# <br>
#
# **참고사이트 : **

# %%
stopwords = ['의', '가', '이', '은', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다']

# %%
import konlpy
from konlpy.tag import Okt
okt = Okt()
X_train = []
for sentence in df_news_copy['nouns_title']:
    tmp_X = okt.morphs(sentence, stem=True) # 토큰화
    tmp_X = [word for word in tmp_X if not word in stopwords] # 불용어 제거
    copy_tmp = tmp_X.copy()
    
    # 단어 길이가 2이상만 추출
    for i in range(len(tmp_X)):
        if len(tmp_X[i]) < 2:
            copy_tmp.remove(tmp_X[i])
    # 대기
    # X_train.append(tmp_X)
    df_news_copy.replace({'nouns_title':sentence}, ' '.join(copy_tmp), inplace=True) # 공백 기준으로 단어 나누기.

# %%
df_news_copy.head(3)
# Out:
#         date  year  month  day                         title  \
# 0 2021-05-01  2021      5    1      DGB대구은행, 은행권 중금리대출 실적 1위
# 1 2021-05-01  2021      5    1  DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원
# 2 2021-05-01  2021      5    1  은행·비은행 동반성장…지방금융지주 1분기 '好好好'
#
#                  nouns_title    press  \
# 0     DGB 대구 은행 은행권 금리 대출 실적  글로벌이코노믹
# 1   DGB 대구 은행 어버이날 맞이 마스크 지원     경북신문
# 2  은행 은행 동반성 지방 금융 지주 1분 好好好     미디어펜
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...
# 1  DGB대구은행(은행장 임성훈)은 다가오는 어버이날을 맞아 지역 내 방역취약계층 어르...
# 2  DGB금융의 순이익은 지난해 1분기에 견줘 40% 급증했다. 핵심 계열사인 대구은행...

# %% [markdown]
# ## 리스트 변환 --> 단어별로 긍정 부정 중립 판단

# %%
df_news_copy.loc[:5, ['nouns_title']]
# nouns 컬럼 --> 공백을 기준으로 나눠 리스트로 변환
df_news_copy['nouns_title'][0].split(' ')
for title_words in df_news_copy['nouns_title'][:5]:
    print(list(title_words.split(' ')))
# Out:
# ['DGB', '대구', '은행', '은행권', '금리', '대출', '실적']
# ['DGB', '대구', '은행', '어버이날', '맞이', '마스크', '지원']
# ['은행', '은행', '동반성', '지방', '금융', '지주', '1분', '好好好']
# ['DGB', '대구', '코로나', '대응', '관련', '유공', '행정안전부', '장관', '표창']
# ['대구', '은행', '방역', '취약', '계층', '어르신', '대상', 'KF', '94', '마스크', '전달']

# %% [markdown]
# ## 레이블링 하기전 파일 저장

# %%
print(df_news_copy.isnull().sum())
# Out:
# date           0
# year           0
# month          0
# day            0
# title          0
# nouns_title    0
# press          0
# contents       0
# dtype: int64

# %%
# 요약내용 제거
# r_title = df_news_copy.copy()
# r_title.drop(columns=['contents'], axis=1, inplace=True)

# %%
# r_title.to_csv('news_data_preprocessing.csv')
df_news_copy.to_csv('news_data_preprocessing.csv')

# %% [markdown]
# ## 뉴스 제목 레이블링
#
# - 긍정 부정 단어를 분류 기초 방식. 따라서 보충이 필요.
#
# ※논문 참고(계산법) : http://www.koreascience.kr/article/JAKO201719363360793.pdf

# %%
import sys
pos_word = []
neg_word = []
pos_neg = []

pos = open('./positive_word.txt', 'r', encoding='UTF-8')

while True:
    line = pos.readline().rstrip()
    pos_word.append(line)
    
    if not line:
        break

pos.close()

neg = open('./negative_word.txt', 'r', encoding='UTF-8')

while True:
    line = neg.readline().rstrip()
    neg_word.append(line)
    
    if not line:
        break

neg.close()

# %%
# 마지막 인덱스 '' 제거
pos_word = pos_word[:-1]
neg_word = neg_word[:-1]
pos_neg = pos_word + neg_word

# %%
state = list()

for x in df_news_copy['nouns_title']:
    words = x.split(' ')
    total, p, n = 0, 0, 0
    
    for i in words:
        if i in pos_word:
            p += 1
        elif i in neg_word:
            n += 1
    
    # 기사 제목당 긍정갯수 - 부정 갯수
    total = p - n
    if total > 0:
        state.append(1)
    elif total == 0:
        state.append(0)
    else:
        state.append(-1)

print('부정:%d   긍정:%d   중립:%d' % (state.count(-1), state.count(1), state.count(0)))

# pd.set_option('mode.chained_assignment',  None) # 경고 off
df_news_copy['label'] = 0
for i in range(len(state)):
    df_news_copy['label'][i] = state[i]
# Out:
# 부정:570   긍정:1410   중립:7017

# %%
df_news_copy[:50]
# Out:
#          date  year  month  day  \
# 0  2021-05-01  2021      5    1
# 1  2021-05-01  2021      5    1
# 2  2021-05-01  2021      5    1
# 3  2021-05-01  2021      5    1
# 4  2021-05-01  2021      5    1
# 5  2021-05-01  2021      5    1
# 6  2021-05-01  2021      5    1
# 7  2021-05-02  2021      5    2
# 8  2021-05-02  2021      5    2
# 9  2021-05-02  2021      5    2
# 10 2021-05-02  2021      5    2
# 11 2021-05-02  2021      5    2
# 12 2021-05-02  2021      5    2
# 13 2021-05-02  2021      5    2
# 14 2021-05-02  2021      5    2
# 15 2021-05-02  2021      5    2
# 16 2021-05-02  2021      5    2
# 17 2021-05-02  2021      5    2
# 18 2021-05-02  2021      5    2
# 19 2021-05-02  2021      5    2
# 20 2021-05-03  2021      5    3
# 21 2021-05-03  2021      5    3
# 22 2021-05-03  2021      5    3
# 23 2021-05-03  2021      5    3
# 24 2021-05-03  2021      5    3
# 25 2021-05-03  2021      5    3
# 26 2021-05-03  2021      5    3
# 27 2021-05-03  2021      5    3
# 28 2021-05-03  2021      5    3
# 29 2021-05-03  2021      5    3
# 30 2021-05-03  2021      5    3
# 31 2021-05-03  2021      5    3
# 32 2021-05-03  2021      5    3
# 33 2021-05-03  2021      5    3
# 34 2021-05-03  2021      5    3
# 35 2021-05-03  2021      5    3
# 36 2021-05-03  2021      5    3
# 37 2021-05-03  2021      5    3
# 38 2021-05-03  2021      5    3
# 39 2021-05-03  2021      5    3
# 40 2021-05-03  2021      5    3
# 41 2021-05-03  2021      5    3
# 42 2021-05-03  2021      5    3
# 43 2021-05-04  2021      5    4
# 44 2021-05-04  2021      5    4
# 45 2021-05-04  2021      5    4
# 46 2021-05-04  2021      5    4
# 47 2021-05-04  2021      5    4
# 48 2021-05-04  2021      5    4
# 49 2021-05-04  2021      5    4
#
#                                             title  \
# 0                        DGB대구은행, 은행권 중금리대출 실적 1위
# 1                    DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원
# 2                    은행·비은행 동반성장…지방금융지주 1분기 '好好好'
# 3               DGB대구銀, 코로나 대응 관련 ‘유공 행정안전부 장관표창’
# 4                 대구은행, 방역취약계층 어르신 대상 KF94 마스크 전달
# 5                   지방금융그룹도 1분기 사상최대 실적…비은행 계열 선전
# 6                    DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원
# 7                  '호실적' 금융지주계열 캐피탈·저축銀…충당금적립 먹구름
# 8                      DGB대구銀, 어버이날 맞이 ‘孝’ 마스크 지원
# 9                   대구시, 지역 빅데이터 역량 집결을 위해 머리 맞댄다
# 10       '한 숨 돌린' BNK·JB·DGB금융 순익 39% 급등…날개 단 비은행
# 11           DGB대구은행, ‘코로나19 적극대응’ 공로 행정안전부 장관 표창
# 12               DGB대구은행, 어버이날 맞아 방역취약계층 효 마스크 지원
# 13      1분기 호실적에 내부등급법 승인 기대감까지 … 지방금융지주 주가 더 오르나
# 14              지방금융지주 1분기 역대급 순이익 ...비은행 '깜짝" 실적
# 15   [SR경제&라이프] 지방금융지주, 주가 30%↑…"깜짝 실적, 주가 추가 상승"
# 16         지방금융지주도 1분기 ‘실적잔치’… 내부등급법 승인땐 몸값 더 오른다
# 17                           코로나19 확산 초기 선제 대응 앞장
# 18                DGB대구은행, 코로나19 대응 유공 행정안전부 장관표창
# 19                      DGB대구은행, 방역취약 어르신에 마스크 지원
# 20                   DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원
# 21                             은행권 가정의 달 이벤트 '풍성'
# 22  [성금내역] 아들 백혈병 투병 중임에도 도박 손대고 연락두절 된 남편으로 힘...
# 23                           시중銀 넘어선 지방銀 수익성…어떻게?
# 24            DGB대구은행 - 한국장학재단, 우편전용 법인카드 발급 업무협약
# 25        DGB금융그룹, 제13회 전국 초·중·고 NIE 에너지일기 공모전 개최
# 26                 DGB대구은행, 비대면 채널 환전·외화적금 경품 이벤트
# 27                DGB대구은행, 6월 말까지 'IM외환딜러' 이벤트 진행
# 28                          대구銀, 비대면 환전·외화적금 경품행사
# 29              DGB대구은행, 비대면 채널 환전 및 외화 적금 가입 이벤트
# 30        DGB대구은행, 비대면 채널 환전 및 외화 적금 가입 고객 경품 이벤트
# 31          DGB대구은행, 비대면 환전·외화 적금 가입 고객 경품 이벤트 실시
# 32           대구은행, 비대면 채널 환전 및 외화 적금 가입 고객 경품 이벤트
# 33                       DGB대구은행, ‘IM외환딜러’ 이벤트 진행
# 34                DGB대구은행, 비대면 환전·외화 적금 가입 경품 이벤트
# 35               대구은행 "비대면으로 환전·외화 적금 들면 경품이 와르르"
# 36             DGB대구銀, 비대면 환전‧외화적금 가입 대상 ‘경품’ 이벤트
# 37           DGB대구은행, 비대면으로 상품과 서비스 이용하면 경품 주는 행사
# 38           DGB대구은행 거점은행 없는 대전충청 본다, 임성훈 지역한계 넘기
# 39        DGB대구은행, 비대면 채널 환전 및 외화 적금 가입 고객 경품 이벤트
# 40                  DGB대구은행, 비대면 환전서비스 등 고객 경품이벤트
# 41                           대구은행 'IM외환딜러 이벤트' 실시
# 42         DGB대구은행, 비대면채널 환전ㆍ외화적금 가입 고객 경품 이벤트 실시
# 43                  DGB대구은행, 'IM외환딜러' 가입 고객 경품 증정
# 44          암호화폐 거래소 문 닫을 판인데… 은행들 “실명계좌 발급? 글쎄요”
# 45               ‘비은행이 효자네’ 지방금융, 1분기 ‘역대급’ 실적 갱신
# 46        [이웃사랑] 더 나은 삶 위해 탈북했지만…남편은 세상 떠나고 딸은 아파
# 47     [더벨][은행경영분석]대구은행, 성공적 '모기지' 전략…대손비용률 역대 최저
# 48        DGB대구은행, 비대면 채널 환전·외화 적금 가입 '경품 이벤트' 실시
# 49            DGB금융그룹, 사회복지지설ㆍ아동금융교육 지원…ESG 경영 실천
#
#                                   nouns_title       press  \
# 0                      DGB 대구 은행 은행권 금리 대출 실적     글로벌이코노믹
# 1                    DGB 대구 은행 어버이날 맞이 마스크 지원        경북신문
# 2                   은행 은행 동반성 지방 금융 지주 1분 好好好        미디어펜
# 3             DGB 대구 코로나 대응 관련 유공 행정안전부 장관 표창        더퍼블릭
# 4          대구 은행 방역 취약 계층 어르신 대상 KF 94 마스크 전달        일요신문
# 5               지방 금융 그룹 1분 사상 최대 실적 은행 계열 선전       e대한경제
# 6                    DGB 대구 은행 어버이날 맞이 마스크 지원        국제뉴스
# 7                 호실 금융 주계열 캐피탈 저축 충당금 적립 먹구름      이코노믹리뷰
# 8                       DGB 대구 어버이날 맞이 마스크 지원        더퍼블릭
# 9                 대구시 지역 빅데이터 역량 집결 위해 머리 맞대다      아시아투데이
# 10               돌리다 BNKJBDGB 금융 39% 급등 날개 은행       에너지경제
# 11      DGB 대구 은행 코로나 19 적극 대응 공로 행정안전부 장관 표창        뉴데일리
# 12          DGB 대구 은행 어버이날 맞다 방역 취약 계층 마스크 지원        뉴데일리
# 13       1분 호실 내부 등급 승인 대감 까지 지방 금융 지주 주가 오르다      파이낸셜뉴스
# 14                지방 금융 지주 1분 역대 순이익 은행 깜짝 실적       브릿지경제
# 15   SR 경제 라이프 지방 금융 지주 주가 30% 깜짝 실적 주가 추가 상승       SR타임스
# 16          지방 금융 주도 1분 실적 잔치 내부 등급 승인 몸값 오르다      파이낸셜뉴스
# 17                      코로나 19 확산 초기 선제 대응 앞장      경북도민일보
# 18         DGB 대구 은행 코로나 19 대응 유공 행정안전부 장관 표창      경상매일신문
# 19                 DGB 대구 은행 방역 취약 어르신 마스크 지원      경상매일신문
# 20                   DGB 대구 은행 어버이날 맞이 마스크 지원      시장경제신문
# 21                                 은행권 가정 이벤트        FETV
# 22      성금 아들 백혈병 투병 중임 에도 도박 손대다 연락 두절 되다 남편        매일신문
# 23                           시중 넘어서다 지방 수익 어떻       헤럴드경제
# 24     DGB 대구 은행 한국 장학재단 우편 전용 법인 카드 발급 업무 협약      브레이크뉴스
# 25      DGB 금융 그룹 13회 전국 중고 NIE 에너지 일기 공모전 개최      브레이크뉴스
# 26            DGB 대구 은행 비대 채널 환전 외화 적금 경품 이벤트         뉴시스
# 27            DGB 대구 은행 6월 까지 IM 외환 딜러 이벤트 진행       데일리한국
# 28                       대구 비대 환전 외화 적금 경품 행사       헤럴드경제
# 29            DGB 대구 은행 비대 채널 환전 외화 적금 가입 이벤트        조세일보
# 30      DGB 대구 은행 비대 채널 환전 외화 적금 가입 고객 경품 이벤트      대한금융신문
# 31      DGB 대구 은행 비대 환전 외화 적금 가입 고객 경품 이벤트 실시       NSP통신
# 32          대구 은행 비대 채널 환전 외화 적금 가입 고객 경품 이벤트        신아일보
# 33                  DGB 대구 은행 IM 외환 딜러 이벤트 진행        쿠키뉴스
# 34            DGB 대구 은행 비대 환전 외화 적금 가입 경품 이벤트      시장경제신문
# 35                대구 은행 대면 환전 외화 적금 들다 경품 와르르      경북도민일보
# 36            DGB 대구 비대 환전 외화 적금 가입 대상 경품 이벤트        더퍼블릭
# 37            DGB 대구 은행 대면 상품 서비스 이용 경품 주다 행사     비즈니스포스트
# 38  DGB 대구 은행 거점 은행 없다 대전 충청 보다 임성훈 지역 한계 넘기다     비즈니스포스트
# 39      DGB 대구 은행 비대 채널 환전 외화 적금 가입 고객 경품 이벤트        국제뉴스
# 40              DGB 대구 은행 비대 환전 서비스 고객 경품 이벤트      경북매일신문
# 41                      대구 은행 IM 외환 딜러 이벤트 실시        대구신문
# 42   DGB 대구 은행 비대 채널 환전 외화 적금 가입 고객 경품 이벤트 실시      경상매일신문
# 43             DGB 대구 은행 IM 외환 딜러 가입 고객 경품 증정        경북일보
# 44            암호 화폐 거래소 닫다 인데 은행 실명 계좌 발급 글쎄요  서울신문언론사 선정
# 45                    은행 효자 지방 금융 1분 역대 실적 갱신        쿠키뉴스
# 46               이웃 사랑 나은 위해 탈북 남편 세상 떠나다 아프다  매일신문언론사 선정
# 47    더벨 은행 경영 분석 대구 은행 성공 모기지 전략 대손 비용 역대 최저          더벨
# 48      DGB 대구 은행 비대 채널 환전 외화 적금 가입 경품 이벤트 실시     파이낸셜투데이
# 49      DGB 금융 그룹 회복 지지 아동 금융 교육 지원 ESG 경영 실천       CNB뉴스
#
#                                              contents  label
# 0   DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...      0
# 1   DGB대구은행(은행장 임성훈)은 다가오는 어버이날을 맞아 지역 내 방역취약계층 어르...      0
# 2   DGB금융의 순이익은 지난해 1분기에 견줘 40% 급증했다. 핵심 계열사인 대구은행...      0
# 3   DGB대구은행(이하 대구은행)은 코로나19 재난 방역 적극 참여 및 지역사회 지원활...      0
# 4   - DGB대구은행, 어버이날 맞아 효(孝) 마스크 지원 DGB대구은행(은행장 임성훈...     -1
# 5   시장금리 상승세에 힘입어 대구은행의 순이자마진이 회복한 데 이어, 비은행 계열인 하...      0
# 6   ▲사진 좌: 서문선 DGB대구은행 경영기획본부장, 송준기 대한적십자사 대구지사 회장...      0
# 7   대구은행 이자이익이 회복되고 비은행 계열사인 DGB캐피탈과 하이투자증권의 이익이 증...      0
# 8   DGB대구은행(은행장 임성훈)은 다가오는 어버이날을 맞아 지역 내 방역취약계층 어
# 39  DGB대구은행(은행장 임성훈)은 3일(월)부터 오는 6월30일까지 비대면 환전서비스...      0
# 40  DGB대구은행(은행장 임성훈)이 오는 6월 30일까지 비대면 환전서비스 이용 및 상...      0
# 41  DGB대구은행은 3일부터 다음 달 30일까지 비대면 환전서비스 이용 및 상품 가입 ...      0
# 42  DGB대구은행은 3일부터 오는 6월30일까지 비대면 환전서비스 이용 및 상품 가입 ...      0
# 43  대구은행 본점 DGB대구은행은 이달 3일부터 오는 6월 30일까지 비대면 환전서비스...      0
# 44  DGB대구은행은 검토 계획이 없다고 했지만, 향후 상황에 따라 발급할 수 있다는 가...      0
# 45  그간 고전을 면치 못하던 대구은행의 이자이익이 회복한데 이어 비은행 계열사인 하이투...      0
# 46  ※ 이웃사랑 성금 보내실 곳 대구은행 069-05-024143-008 / 우체국 7...      0
# 47  *출처=DGB금융지주 마진 자체는 줄어들 수밖에 없었다. 대구은행의 대출수익률은 수...      0
# 48  사진=DGB대구은행 DGB대구은행은 오는 6월 30일까지 비대면 환전서비스 이용 및...      0
# 49  (사진=대구은행 제공) DGB금융그룹이 지역 대표 기업으로써 지역 장애인 및 아동 ...      0

# %% [markdown]
# ## 중립 개수가 너무 많음.
# - 제목별로 단어개수를 파악해서 긍정단어사전과 부정단어사전을 만들어서 레이블링 작업 진행해야 함.
# - 기사당 긍정단어개수 - 부정단어개수가 0보다 크면 긍정 작으면 부정 0이라면 중립으로 진행

# %% [markdown]
# ### 현재까지 나온 데이터 프레임을 통해 Train Set과 Test Set으로 분류 ( 7:3 정도 ) / 분류할 때 데이터를 적절하게 분배해야 함. Ex) 1~12월이 있다면  30퍼를 12로 나눠야 함.

# %% [markdown]
# # 그래프 분석 (EDA)
# <br>
#
# **언론사별 / 월별 / 주중별기사 수량 확인**
#
#     ▶ 언론사를 각 숫자로 표현 후 EDA 실시 Ex) 1 : 미디어펜, 2 : 아이뉴스24, 3 : 데일리안 ...
#     ▶ date : 등록된 기사별 날짜
# **아직 제대로 진행 안됨...**

# %%
# 날짜별 데이터 갯수
df_news_copy.groupby('date').count().head(3)
# Out:
#             year  month  day  title  nouns_title  press  contents  label
# date
# 2021-05-01     7      7    7      7            7      7         7      7
# 2021-05-02    13     13   13     13           13     13        13     13
# 2021-05-03    23     23   23     23           23     23        23     23

# %% [markdown]
# ## 월별 기사 갯수
# <br>
#
# **참고사이트 : https://zephyrus1111.tistory.com/9**

# %%
# 시각화 글자 깨짐 방지
import os

if os.name == 'posix':
    plt.rc("font", family="AppleGothic")
else:
    plt.rc("font", family="Malgun Gothic")

# %%
df_news.head()
# Out:
#         date  year  month  day                              title    press  \
# 0 2021-05-01  2021      5    1           DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
# 1 2021-05-01  2021      5    1       DGB대구은행, 어버이날 맞이 효(孝) 마스크 지원     경북신문
# 2 2021-05-01  2021      5    1       은행·비은행 동반성장…지방금융지주 1분기 '好好好'     미디어펜
# 3 2021-05-01  2021      5    1  DGB대구銀, 코로나 대응 관련 ‘유공 행정안전부 장관표창’     더퍼블릭
# 4 2021-05-01  2021      5    1    대구은행, 방역취약계층 어르신 대상 KF94 마스크 전달     일요신문
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...
# 1  DGB대구은행(은행장 임성훈)은 다가오는 어버이날을 맞아 지역 내 방역취약계층 어르...
# 2  DGB금융의 순이익은 지난해 1분기에 견줘 40% 급증했다. 핵심 계열사인 대구은행...
# 3  DGB대구은행(이하 대구은행)은 코로나19 재난 방역 적극 참여 및 지역사회 지원활...
# 4  - DGB대구은행, 어버이날 맞아 효(孝) 마스크 지원 DGB대구은행(은행장 임성훈...

# %%
df_news.hist(figsize = (16, 12))
plt.show()

# %%
df_news_copy['month'].unique()
x = df_news_copy['month'].value_counts().index.tolist()
y = df_news_copy['month'].value_counts().values.tolist()

# %%
plt.figure(figsize = (16, 8))

sns.countplot(x='month', data=df_news_copy, color='pink') # #FC7F77

for i, v in enumerate(x):
    plt.text(v-1, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 15, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)
    
plt.xlabel('월별', size = 20, labelpad=20) # x축 제목 설정
plt.ylabel('갯수', size = 20, labelpad=20) #y축 제목 설정, 빨간 글씨
plt.rc('xtick', labelsize=20)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.title('뉴스 기사', size = 25)
plt.show()

# %% [markdown]
# ## 언론사별 기사 갯수
# - 언론사별 범주형 데이터 --> 수치형으로 변환

# %%
df_news.head(1)
# Out:
#         date  year  month  day                     title    press  \
# 0 2021-05-01  2021      5    1  DGB대구은행, 은행권 중금리대출 실적 1위  글로벌이코노믹
#
#                                             contents
# 0  DGB대구은행의 중금리대출 실적이 지방은행뿐만 아니라 은행권 전체에서 가장 많은 것...

# %%
len(df_news['press'].unique())
df_news['press'].unique()
# Out:
# array(['글로벌이코노믹', '경북신문', '미디어펜', '더퍼블릭', '일요신문', 'e대한경제', '국제뉴스',
#        '이코노믹리뷰', '아시아투데이', '에너지경제', '뉴데일리', '파이낸셜뉴스', '브릿지경제', 'SR타임스',
#        '경북도민일보', '경상매일신문', '시장경제신문', 'FETV', '매일신문', '헤럴드경제', '브레이크뉴스',
#        '뉴시스', '데일리한국', '조세일보', '대한금융신문', 'NSP통신', '신아일보', '쿠키뉴스',
#        '비즈니스포스트', '경북매일신문', '대구신문', '경북일보', '서울신문언론사 선정', '매일신문언론사 선정',
#        '더벨', '파이낸셜투데이', 'CNB뉴스', '아시아경제', '스마트에프엔', '서울파이낸스', '메트로신문',
#        'BBS NEWS', '뉴스클레임', '스트레이트뉴스', '퍼블릭뉴스', '매일일보', '영남일보', '한스경제',
#        '이투데이', '연합인포맥스', '노컷뉴스', '조선비즈', '프레시안', '뉴스저널리즘', '머니투데이',
#        '더팩트언론사 선정', 'SBS Biz', '서울경제', '메가경제', '아시아에이', '뉴스핌', '머니S',
#        '시사뉴스', '대구일보', '한국일보', '공감신문', '현대경제신문', '아주경제', '이데일리', '인더뉴스',
#        '내외경제tv', '로이슈', '뉴스웨이', '뉴스투데이', '연합뉴스', '전국매일신문', '스포츠서울',
#        'TBC대구방송', '매경이코노미언론사 선정', '머니S언론사 선정', '뉴스락', '컨슈머타임스', '시사오늘',
#        '팍스경제TV', '청년일보', '뉴스웍스', '업다운뉴스', '데일리안', 'EBN', '아시아타임즈', '더퍼스트',
#        '프라임경제', 'CEO스코어데일리', '비욘드포스트', '전자신문언론사 선정', '여성소비자신문', '위클리오늘',
#        '뉴스토마토', '화이트페이퍼', '대구MBC', '위키트리', '위키리크스한국', 'KBS', '세이프타임즈',
#        '팍스넷뉴스', '증권경제신문', '전자신문', '아이뉴스24', '민주신문', '디지털타임스', '천지일보',
#        '잡포스트', '한국금융신문', '스마트경제', '대전일보', '시사포커스', '디자인정글', '뷰어스',
#        '굿모닝경제', '서울경제TV', '이데일리언론사 선정', '한국경제', '조세금융신문', '파이낸셜뉴스언론사 선정',
#        '세계일보', '한국경제TV', '라이센스뉴스', '소비자가 만드는 신문', '핀포인트뉴스', '비즈월드',
#        '대경일보', '국민일보', '세계비즈', '서울와이어', '조선일보', '국토일보', '포쓰저널', '베이비뉴스',
#        '뉴스1', '시사저널이코노미', '중소기업신문', '파이낸셜신문', '디지털데일리', '남도일보', '데이터뉴스',
#        '의학신문', '세정신문', '한경비즈니스', '뉴스케이프', '서울신문', '이뉴스투데이',
#        '한경비즈니스언론사 선정', '워크투데이', '한국정경신문', '조선비즈언론사 선정', '이코노미스트', '내일신문',
#        '경향신문언론사 선정', '매일경제', '매일경제언론사 선정', '제주매일', '아시아경제언론사 선정', 'IT조선',
#        '지이코노미', '뉴스워치', '비즈니스워치언론사 선정', '그린포스트코리아', '블로터언론사 선정', '경향신문',
#        '오피니언뉴스', '데일리임팩트', '베리타스알파', '오늘경제', '김해뉴스', '보안뉴스', '더드라이브',
#        '중소기업뉴스', '뉴스경남', '이코노미스트언론사 선정', 'AI타임스', '문화일보', 'TV조선', '뉴스포스트',
#        '데일리안언론사 선정', '경남도민일보', '월요신문', '매일노동뉴스', ' 케이조선 ', '동아일보', '한겨레',
#        '독서신문', '한국경제TV언론사 선정', '스타뉴스', 'MTN', 'SBS Biz언론사 선정', '비즈니스워치',
#        '노컷뉴스언론사 선정', '더파워', '아이뉴스24언론사 선정', '싱글리스트', '투데이코리아', '우먼타임스',
#        '오마이뉴스', '프레스맨', '금융소비자뉴스', '시사위크', '스카이데일리', '시사저널', '중앙일보',
#        '글로벌경제', 'ZDNet Korea', '테크M', 'HCN 새로넷방송', '딜라이트닷넷', '빅데이터뉴스',
#        '더밸류뉴스', '부산일보언론사 선정', 'MBN', '디지털투데이', '이코노뉴스', '울산매일신문',
#        '아웃소싱타임스', '이지경제', '데일리팝', '테크월드', '데일리메디', '뉴스프리존', '유교신문',
#        '조세일보언론사 선정', '뉴시스언론사 선정', '뉴스1언론사 선정', '매경이코노미', '에너지데일리',
#        '투데이에너지', '인천in', '점프볼', '데이터넷', '에이블뉴스', '연합뉴스언론사 선정',
#        '머니투데이언론사 선정', '플래텀', '더팩트', '금강일보', '베타뉴스', '공공뉴스', '머니',
#        '블록체인밸리', '주간조선언론사 선정', '벤처스퀘어', '더구루', '데일리경제', '땅집고', '데일리스포츠한국',
#        '전남일보', '투데이신문', '울산제일일보', '한국경제언론사 선정', '동아일보언론사 선정', '인사이트코리아',
#        'YTN', '시민일보', '매일경제TV', '서울이코노미뉴스', '포항MBC', '안동MBC', 'MBC언론사 선정',
#        '뉴스브라이트', '뉴스워커', '중도일보', '스포츠한국', 'MK스포츠', 'IT비즈뉴스', '주간동아언론사 선정',
#        'UPI뉴스', '비지니스코리아', '오피니언타임스', '충청타임즈', '넥스트데일리', 'CIO Korea',
#        '브레인미디어', '여성신문', 'ZDNet Korea언론사 선정', 'ITWorld', '정보통신신문',
#        '인공지능신문', '스포츠경향', '푸드경제신문 organiclife', '시선뉴스', '베이비타임즈',
#        '대구MBC언론사 선정', '디지털데일리언론사 선정', '포춘코리아', ' 유진투자증권 ', '중앙일보언론사 선정',
#        '헬로디디', '중앙SUNDAY', '경기신문', '뉴시안', '국민일보언론사 선정', '한국보험신문',
#        '인베스트조선', '농업경제신문', '디아이투데이', '헬로티', '아이티데일리', '바이라인네트워크',
#        '한국무역신문', '농민신문', '열린뉴스통신', '메디컬투데이', '경인매일', '뉴스민', '불교신문',
#        'S-저널'], dtype=object)

# %%
df_news_copy['press'].unique()
x = df_news_copy['press'].value_counts().index.tolist()
y = df_news_copy['press'].value_counts().values.tolist()

# %%
# 기사 갯수가 75 이상인 것만
limit = 0
for idx, value  in enumerate(y):
    if value < 75:
        limit = idx
        break

x = x[:limit]
y = y[:limit]

# %%
df_news_copy['press'].value_counts()[50:]
# Out:
# 내외경제tv        56
# 팍스경제TV        55
# 이뉴스투데이        55
# 더퍼블릭          54
# 노컷뉴스          53
#               ..
# 연합뉴스언론사 선정     1
# 여성신문           1
# 울산제일일보         1
# 울산매일신문         1
# 금강일보           1
# Name: press, Length: 264, dtype: int64

# %%
plt.figure(figsize = (42, 12))

for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 15, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

plt.title('언론사별 기사 개수', fontsize = 20)
plt.bar(x, y, width=0.5)
plt.xticks(rotation = -45)
plt.xlabel('count', fontsize=20)
plt.ylabel('press', fontsize=20)
plt.show()

# %% [markdown]
# # 해야할 것들
# - 이슈분석지표 워드 클라우드는 이제 단어별 갯수 구한 후 표 그리면 완성
# - 감정분석
# <br><br>
# - 1. 현재 사용중인 CSV파일이 아닌 1년치 데이터를 스크래핑
# <br><br>
# - 2. 스크래핑한 데이터의 갯수가 50000개의 데이터라면 / Train_set : 70% Test_set : 30%로 분할 (랜덤모듈이용)<br>
# ※ 단, Test_set 분할시 2.5%로 12개월분할하면 제일 좋음 ( 매달마다 2.5%의 Test_set를 뽑아와서 총 30%로 만듬.) 1~12월 골고루 뽑아올 수 있음.
# <br><br>
# - 3. Train_set에 Labeling을 해주어야 함. (긍정 1, 부정 -1, 중립 0)
# <br>
# ※ Labeling 할 때 어떤식으로 정답을 부여할지 생각해야 됨.
